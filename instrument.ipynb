# %%
import requests
import defs
import pandas as pd

# %%
session = requests.Session()

# %%
instrument = "EUR_USD"
count = 10
granularity = "H1"

# %%
params = dict(
    count = count,
    granularity = granularity,
    price="MBA"
)
params
# Out:
# {'count': 10, 'granularity': 'H1', 'price': 'MBA'}

# %%
url = f"{defs.OANDA_URL}/instruments/{instrument}/candles"
url
# Out:
# 'https://api-fxpractice.oanda.com/v3/instruments/EUR_USD/candles'

# %%
response = session.get(url, params=params, headers=defs.SECURE_HEADER).json()
response
# Out:
# {'instrument': 'EUR_USD',
#  'granularity': 'H1',
#  'candles': [{'complete': True,
#    'volume': 2731,
#    'time': '2023-07-05T19:00:00.000000000Z',
#    'bid': {'o': '1.08532', 'h': '1.08562', 'l': '1.08517', 'c': '1.08546'},
#    'mid': {'o': '1.08538', 'h': '1.08569', 'l': '1.08526', 'c': '1.08552'},
#    'ask': {'o': '1.08544', 'h': '1.08576', 'l': '1.08532', 'c': '1.08558'}},
#   {'complete': True,
#    'volume': 1162,
#    'time': '2023-07-05T20:00:00.000000000Z',
#    'bid': {'o': '1.08545', 'h': '1.08552', 'l': '1.08523', 'c': '1.08524'},
#    'mid': {'o': '1.08552', 'h': '1.08558', 'l': '1.08530', 'c': '1.08534'},
#    'ask': {'o': '1.08559', 'h': '1.08564', 'l': '1.08538', 'c': '1.08543'}},
#   {'complete': True,
#    'volume': 535,
#    'time': '2023-07-05T21:00:00.000000000Z',
#    'bid': {'o': '1.08524', 'h': '1.08553', 'l': '1.08514', 'c': '1.08545'},
#    'mid': {'o': '1.08574', 'h': '1.08576', 'l': '1.08541', 'c': '1.08569'},
#    'ask': {'o': '1.08624', 'h': '1.08624', 'l': '1.08553', 'c': '1.08593'}},
#   {'complete': True,
#    'volume': 659,
#    'time': '2023-07-05T22:00:00.000000000Z',
#    'bid': {'o': '1.08540', 'h': '1.08565', 'l': '1.08519', 'c': '1.08522'},
#    'mid': {'o': '1.08567', 'h': '1.08572', 'l': '1.08528', 'c': '1.08530'},
#    'ask': {'o': '1.08594', 'h': '1.08597', 'l': '1.08536', 'c': '1.08538'}},
#   {'complete': True,
#    'volume': 624,
#    'time': '2023-07-05T23:00:00.000000000Z',
#    'bid': {'o': '1.08524', 'h': '1.08556', 'l': '1.08513', 'c': '1.08546'},
#    'mid': {'o': '1.08532', 'h': '1.08564', 'l': '1.08521', 'c': '1.08554'},
#    'ask': {'o': '1.08539', 'h': '1.08573', 'l': '1.08528', 'c': '1.08561'}},
#   {'complete': True,
#    'volume': 2164,
#    'time': '2023-07-06T00:00:00.000000000Z',
#    'bid': {'o': '1.08548', 'h': '1.08554', 'l': '1.08456', 'c': '1.08483'},
#    'mid': {'o': '1.08555', 'h': '1.08562', 'l': '1.08464', 'c': '1.08490'},
#    'ask': {'o': '1.08562', 'h': '1.08569', 'l': '1.08471', 'c': '1.08497'}},
#   {'complete': True,
#    'volume': 3022,
#    'time': '2023-07-06T01:00:00.000000000Z',
#    'bid': {'o': '1.08482', 'h': '1.08500', 'l': '1.08421', 'c': '1.08494'},
#    'mid': {'o': '1.08490', 'h': '1.08508', 'l': '1.08428', 'c': '1.08501'},
#    'ask': {'o': '1.08497', 'h': '1.08515', 'l': '1.08435', 'c': '1.08508'}},
#   {'complete': True,
#    'volume': 2059,
#    'time': '2023-07-06T02:00:00.000000000Z',
# {'complete': True, 'volume': 3022, 'time': '2023-07-06T01:00:00.000000000Z', 'bid': {'o': '1.08482', 'h': '1.08500', 'l': '1.08421', 'c': '1.08494'}, 'mid': {'o': '1.08490', 'h': '1.08508', 'l': '1.08428', 'c': '1.08501'}, 'ask': {'o': '1.08497', 'h': '1.08515', 'l': '1.08435', 'c': '1.08508'}}
# {'complete': True, 'volume': 2059, 'time': '2023-07-06T02:00:00.000000000Z', 'bid': {'o': '1.08492', 'h': '1.08529', 'l': '1.08452', 'c': '1.08464'}, 'mid': {'o': '1.08500', 'h': '1.08537', 'l': '1.08460', 'c': '1.08472'}, 'ask': {'o': '1.08508', 'h': '1.08545', 'l': '1.08467', 'c': '1.08479'}}
# {'complete': True, 'volume': 2086, 'time': '2023-07-06T03:00:00.000000000Z', 'bid': {'o': '1.08463', 'h': '1.08463', 'l': '1.08392', 'c': '1.08396'}, 'mid': {'o': '1.08470', 'h': '1.08470', 'l': '1.08399', 'c': '1.08402'}, 'ask': {'o': '1.08477', 'h': '1.08478', 'l': '1.08405', 'c': '1.08409'}}
# {'complete': False, 'volume': 2178, 'time': '2023-07-06T04:00:00.000000000Z', 'bid': {'o': '1.08392', 'h': '1.08407', 'l': '1.08331', 'c': '1.08407'}, 'mid': {'o': '1.08398', 'h': '1.08414', 'l': '1.08338', 'c': '1.08414'}, 'ask': {'o': '1.08405', 'h': '1.08421', 'l': '1.08345', 'c': '1.08420'}}

# %%
response.keys()
# Out:
# dict_keys(['instrument', 'granularity', 'candles'])

# %%
len(response["candles"])
# Out:
# 10

# %%
print(type(ticker))
for ticker in response["instrument"]:
    print(response["instrument"])
    print(f"{ticker}, Volume {candle['volume']} at {candle['time']}")
# Out:
# <class 'str'>
# EUR_USD
# E, Volume 2178 at 2023-07-06T04:00:00.000000000Z
# EUR_USD
# U, Volume 2178 at 2023-07-06T04:00:00.000000000Z
# EUR_USD
# R, Volume 2178 at 2023-07-06T04:00:00.000000000Z
# EUR_USD
# _, Volume 2178 at 2023-07-06T04:00:00.000000000Z
# EUR_USD
# U, Volume 2178 at 2023-07-06T04:00:00.000000000Z
# EUR_USD
# S, Volume 2178 at 2023-07-06T04:00:00.000000000Z
# EUR_USD
# D, Volume 2178 at 2023-07-06T04:00:00.000000000Z

# %%
prices = ["mid", "bid", "ask"]
ohlc = ["o", "h", "l", "c"]

# %%
for price in prices:
    for oh in ohlc:
        print(f"{price}_{oh}")
# Out:
# mid_o
# mid_h
# mid_l
# mid_c
# bid_o
# bid_h
# bid_l
# bid_c
# ask_o
# ask_h
# ask_l
# ask_c

# %%
our_data = []
new_dict = dict()

for ticker in response["instrument"]:
    new_dict["ticker"] = response["instrument"]
                                  
    for candle in response["candles"]:
        if candle["complete"] == False:
            continue


        new_dict["time"] = candle["time"]
        new_dict["volume"] = candle["volume"]

        for price in prices:
            for oh in ohlc:
                new_dict[f"{price}_{oh}"] = candle[price][oh]
                our_data.append(new_dict)

# %%
print(our_data)
# Out:
# [{'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c': '1.08402', 'bid_o': '1.08463', 'bid_h': '1.08463', 'bid_l': '1.08392', 'bid_c': '1.08396', 'ask_o': '1.08477', 'ask_h': '1.08478', 'ask_l': '1.08405', 'ask_c': '1.08409'}, {'ticker': 'EUR_USD', 'time': '2023-07-06T03:00:00.000000000Z', 'volume': 2086, 'mid_o': '1.08470', 'mid_h': '1.08470', 'mid_l': '1.08399', 'mid_c' ...

# %%
candles_df = pd.DataFrame.from_dict(our_data)
candles_df.to_csv("checkpoint.csv")
